# %% [markdown]
# <a href="https://colab.research.google.com/github/1Yunsu1/Study/blob/main/Cat_Gray.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread('SuriNoel_Raon.jpg', 1)
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(image, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])
plt.show()
